# %% [markdown]
# ## TODO
#
# - [ ] Lazy Load -> https://github.com/qubvel/segmentation_models/blob/master/examples/multiclass%20segmentation%20(camvid).ipynb
# - [ ] Satllite Preprocessing

# %%
import rioxarray
import xarray as xr
import numpy as np
import os
from glob import glob
from tqdm.notebook import tqdm

# %%
class Dataset():
    def __init__(self, image_path:str, mask_path:str):
        
        self.image_dir,_ = os.path.split(image_path)
        self.mask_dir,_  = os.path.split(mask_path)

        if(os.path.exists(self.image_dir) == False):
            raise FileExistsError(f"{self.image_dir} not exist")
        if(os.path.exists(self.mask_dir) == False):
            raise FileExistsError(f"{self.mask_dir} not exist")
        
        images = sorted(glob(image_path))
        masks = sorted(glob(mask_path))

        if(len(images) != len(masks)):
            raise ValueError(f"Expect number of {len(images)=} equal to {len(masks)=}")
        
        self.postfixes = []

        for image, mask in tqdm(list(zip(images, masks))):
            _,image_name = os.path.split(image)
            _,mask_name = os.path.split(mask)
            image_name,_ = os.path.splitext(image_name)
            mask_name,_ = os.path.splitext(mask_name)
            image_name = image_name.split('_')
            mask_name = mask_name.split('_')
            if(image_name[1] != mask_name[1] and image_name[2] != mask_name[2]):
                raise NameError(f"{image_name=} {mask_name=}")
            coord = f"_{mask_name[1]}_{mask_name[2]}.tif"
            self.postfixes.append(coord)


        # self.img_labels = pd.read_csv(annotations_file)
        # self.img_dir = img_dir
        # self.transform = transform
        # self.target_transform = target_transform

    def __len__(self):
        return len(self.img_labels)

    def __getitem__(self, idx):
        img_path = os.path.join(self.img_dir, self.img_labels.iloc[idx, 0])
        image = read_image(img_path)
        label = self.img_labels.iloc[idx, 1]
        if self.transform:
            image = self.transform(image)
        if self.target_transform:
            label = self.target_transform(label)
        return image, label

# %%
image_path = "../data/Sample1_tile/image/*.tif"
mask_path = "../data/Sample1_tile/mask/*.tif"

ds = Dataset(image_path=image_path, mask_path=mask_path)
# Out:
#   0%|          | 0/21509 [00:00<?, ?it/s]

# %%
ds.postfixes
# Out:
# ['_0_0.tif',
#  '_0_1024.tif',
#  '_0_10240.tif',
#  '_0_10752.tif',
#  '_0_11264.tif',
#  '_0_11776.tif',
#  '_0_12288.tif',
#  '_0_12800.tif',
#  '_0_13312.tif',
#  '_0_13824.tif',
#  '_0_14336.tif',
#  '_0_14848.tif',
#  '_0_1536.tif',
#  '_0_15360.tif',
#  '_0_15872.tif',
#  '_0_16384.tif',
#  '_0_16896.tif',
#  '_0_17408.tif',
#  '_0_17920.tif',
#  '_0_18432.tif',
#  '_0_18944.tif',
#  '_0_19456.tif',
#  '_0_19968.tif',
#  '_0_2048.tif',
#  '_0_20480.tif',
#  '_0_20992.tif',
#  '_0_21504.tif',
#  '_0_22016.tif',
#  '_0_22528.tif',
#  '_0_23040.tif',
#  '_0_23552.tif',
#  '_0_24064.tif',
#  '_0_24576.tif',
#  '_0_25088.tif',
#  '_0_2560.tif',
#  '_0_25600.tif',
#  '_0_26112.tif',
#  '_0_26624.tif',
#  '_0_27136.tif',
#  '_0_27648.tif',
#  '_0_28160.tif',
#  '_0_28672.tif',
#  '_0_29184.tif',
#  '_0_29696.tif',
#  '_0_30208.tif',
#  '_0_3072.tif',
#  '_0_30720.tif',
#  '_0_31232.tif',
#  '_0_31744.tif',
#  '_0_32256.tif',
#  '_0_32768.tif',
#  '_0_33280.tif',
#  '_0_33792.tif',
#  '_0_34304.tif',
#  '_0_34816.tif',
#  '_0_35328.tif',
#  '_0_3584.tif',
#  '_0_35840.tif',
#  '_12288_23040.tif',
#  '_12288_23552.tif',
#  '_12288_24064.tif',
#  '_12288_24576.tif',
#  '_12288_25088.tif',
#  '_12288_2560.tif',
#  '_12288_25600.tif',
#  '_12288_26112.tif',
#  '_12288_26624.tif',
#  '_12288_27136.tif',
#  '_12288_27648.tif',
#  '_12288_28160.tif',
#  '_12288_28672.tif',
#  '_12288_29184.tif',
#  '_12288_29696.tif',
#  '_12288_30208.tif',
#  '_12288_3072.tif',
#  '_12288_30720.tif',
#  '_12288_31232.tif',
#  '_12288_31744.tif',
#  '_12288_32256.tif',
#  '_12288_32768.tif',
#  '_12288_33280.tif',
#  '_12288_33792.tif',
#  '_12288_34304.tif',
#  '_12288_34816.tif',
#  '_12288_35328.tif',
#  '_12288_3584.tif',
#  '_12288_35840.tif',
#  ...]

# %%
images = sorted(glob("../data/Sample1_tile/image/*.tif"))
masks = sorted(glob("../data/Sample1_tile/mask/*.tif"))

# %%
X = []
Y = []
# samples = np.inf
samples = 500
count = 0
for image, mask in tqdm(list(zip(images, masks))):
    _,image_name = os.path.split(image)
    _,mask_name = os.path.split(mask)
    image_name,_ = os.path.splitext(image_name)
    mask_name,_ = os.path.splitext(mask_name)
    image_name = image_name.split('_')
    mask_name = mask_name.split('_')
    if(image_name[1] != mask_name[1] and image_name[2] != mask_name[2]):
        raise NameError(f"{image_name=} {mask_name=}")
    
    x:xr.DataArray = rioxarray.open_rasterio(image)
    y:xr.DataArray = rioxarray.open_rasterio(mask)

    x = x.data
    if(x.shape[1] < 512):
        pad = 512 - x.shape[1]
        pad = np.zeros(shape=(3,pad,x.shape[2]))
        x = np.concatenate([x,pad], axis=1)
    if(x.shape[2] < 512):
        pad = 512 - x.shape[2]
        pad = np.zeros(shape=(3,x.shape[1],pad))
        x = np.concatenate([x,pad], axis=2)
    
    y = y.data
    if(y.shape[1] < 512):
        pad = 512 - y.shape[1]
        pad = np.zeros(shape=(1,pad,y.shape[2]))
        y = np.concatenate([y,pad], axis=1)
    if(y.shape[2] < 512):
        pad = 512 - y.shape[2]
        pad = np.zeros(shape=(1,y.shape[1],pad))
        y = np.concatenate([y,pad], axis=2)

    X.append(np.expand_dims(x, axis=0))
    Y.append(y)
    count += 1
    if(count >= samples):
        break
# Out:
#   0%|          | 0/21509 [00:00<?, ?it/s]

# %%
X = np.vstack(X).astype(np.float32)
Y = np.vstack(Y).astype(np.float32)
X.shape, Y.shape
# Out:
# ((500, 3, 512, 512), (500, 512, 512))

# %%
X = X.swapaxes(1,2).swapaxes(2,3)

# %%
X.shape
# Out:
# (500, 512, 512, 3)

# %%
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm
# Out:
# 2024-07-22 10:44:36.143747: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-22 10:44:36.155142: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-22 10:44:36.158578: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-22 10:44:36.167416: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-22 10:44:38.426457: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Segmentation Models: using `tf.keras` framework.

# %%
from segmentation_models import Unet
from segmentation_models import get_preprocessing
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score
import keras

BACKBONE = 'inceptionresnetv2'
preprocess_input = get_preprocessing(BACKBONE)

# load your data
# x_train, y_train, x_val, y_val = load_data(...)

# preprocess input
X = preprocess_input(X)
# define model
model = Unet(BACKBONE, classes=1, encoder_weights='imagenet', encoder_freeze=True,)
loss = sm.losses.DiceLoss()
metrics = [sm.metrics.IOUScore(),'binary_accuracy',keras.metrics.Precision(),keras.metrics.Recall()]
model.compile("Adam", loss=loss, metrics=metrics)

# display_cb = DisplayCallback()
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights='True')
checkpoint_cb = keras.callbacks.ModelCheckpoint('../weights/model_unet-inceptionresnetv2_cp.keras', verbose=1, save_best_only=True)

# fit model
model.fit(
    x=X,
    y=Y,
    batch_size=1,
    epochs=100,
    validation_data=(X, Y),
    callbacks=[early_stopping_cb, checkpoint_cb],
)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721619880.485456  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.512080  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.512271  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.513883  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.514027  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.514151  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.563021  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.563187  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# I0000 00:00:1721619880.563322  174227 cuda_executor.cc:1015] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-22 10:44:40.563423: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2021] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6273 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070 Ti, pci bus id: 0000:06:10.0, compute capability: 8.6
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1721619918.028829  174587 service.cc:146] XLA service 0x7f7a28003840 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1721619918.028861  174587 service.cc:154]   StreamExecutor device (0): NVIDIA GeForce RTX 3070 Ti, Compute Capability 8.6
# 2024-07-22 10:45:19.447761: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-07-22 10:45:24.029564: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:531] Loaded cuDNN version 8907
# 2024-07-22 10:45:35.158046: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 9.16GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 2024-07-22 10:45:35.369747: W external/local_tsl/tsl/framework/bfc_allocator.cc:291] Allocator (GPU_0_bfc) ran out of memory trying to allocate 10.10GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   1/500 ━━━━━━━━━━━━━━━━━━━━ 10:18:56 74s/step - binary_accuracy: 0.2730 - iou_score: 6.4052e-11 - loss: 1.0000 - precision: 0.0000e+00 - recall: 0.0000e+00
# I0000 00:00:1721619960.368326  174587 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.5720 - iou_score: 6.7686e-04 - loss: 0.9984 - precision: 0.0014 - recall: 0.8070
# Epoch 1: val_loss improved from inf to 0.99909, saving model to ../weights/model_unet-inceptionresnetv2_cp.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 125s 101ms/step - binary_accuracy: 0.5722 - iou_score: 6.7624e-04 - loss: 0.9984 - precision: 0.0014 - recall: 0.8070 - val_binary_accuracy: 0.6683 - val_iou_score: 4.1574e-04 - val_loss: 0.9991 - val_precision: 0.0012 - val_recall: 1.0000
# Epoch 2/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.7471 - iou_score: 3.8470e-04 - loss: 0.9986 - precision: 0.0012 - recall: 0.7049
# Epoch 2: val_loss improved from 0.99909 to 0.99904, saving model to ../weights/model_unet-inceptionresnetv2_cp.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 41s 82ms/step - binary_accuracy: 0.7472 - iou_score: 3.8465e-04 - loss: 0.9986 - precision: 0.0012 - recall: 0.7051 - val_binary_accuracy: 0.6942 - val_iou_score: 4.2785e-04 - val_loss: 0.9990 - val_precision: 0.0013 - val_recall: 1.0000
# Epoch 3/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9214 - iou_score: 1.4969e-04 - loss: 0.9979 - precision: 0.0032 - recall: 0.5137
# Epoch 3: val_loss did not improve from 0.99904
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 39s 77ms/step - binary_accuracy: 0.9214 - iou_score: 1.4979e-04 - loss: 0.9979 - precision: 0.0032 - recall: 0.5136 - val_binary_accuracy: 0.9798 - val_iou_score: 1.3739e-04 - val_loss: 0.9999 - val_precision: 1.1566e-05 - val_recall: 5.8517e-04
# Epoch 4/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - binary_accuracy: 0.8203 - iou_score: 1.1299e-04 - loss: 0.9990 - precision: 6.9191e-04 - recall: 0.2627
# Epoch 4: val_loss improved from 0.99904 to 0.99881, saving model to ../weights/model_unet-inceptionresnetv2_cp.keras
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 40s 81ms/step - binary_accuracy: 0.8203 - iou_score: 1.1311e-04 - loss: 0.9990 - precision: 6.9324e-04 - recall: 0.2632 - val_binary_accuracy: 0.7678 - val_iou_score: 4.4327e-04 - val_loss: 0.9988 - val_precision: 0.0017 - val_recall: 0.9872
# Epoch 5/100
# 500/500 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - binary_accuracy: 0.9056 - iou_score: 2.1351e-04 - loss: 0.9968 - precision: 0.0028 - recall: 0.5174
# Epoch 5: val_loss improved from 0.99881 to 0.99845, saving model to ../weights/model_unet-inceptionresnetv2_cp.keras
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 26
#      23 checkpoint_cb = keras.callbacks.ModelCheckpoint('../weights/model_unet-inceptionresnetv2_cp.keras', verbose=1, save_best_only=True)
#      25 # fit model
# ---> 26 model.fit(
#      27     x=X,
#      28     y=Y,
#      29     batch_size=1,
#      30     epochs=100,
#      31     validation_data=(X, Y),
#      32     callbacks=[early_stopping_cb, checkpoint_cb],
#      33 )
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:358, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     353     val_logs = {
#     354         "val_" + name: val for name, val in val_logs.items()
#     355     }
#     356     epoch_logs.update(val_logs)
# --> 358 callbacks.on_epoch_end(epoch, epoch_logs)
#     359 training_logs = epoch_logs
#     360 if self.stop_training:
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/callbacks/callback_list.py:96, in CallbackList.on_epoch_end(self, epoch, logs)
#      94 logs = logs or {}
#      95 for callback in self.callbacks:
# ---> 96     callback.on_epoch_end(epoch, logs)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/callbacks/model_checkpoint.py:206, in ModelCheckpoint.on_epoch_end(self, epoch, logs)
#     204 def on_epoch_end(self, epoch, logs=None):
#     205     if self.save_freq == "epoch":
# --> 206         self._save_model(epoch=epoch, batch=None, logs=logs)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/callbacks/model_checkpoint.py:273, in ModelCheckpoint._save_model(self, epoch, batch, logs)
#     271         self.model.save_weights(filepath, overwrite=True)
#     272     else:
# --> 273         self.model.save(filepath, overwrite=True)
#     274 else:
#     275     if self.verbose > 0:
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/models/model.py:307, in Model.save(self, filepath, overwrite, zipped, **kwargs)
#     267 @traceback_utils.filter_traceback
#     268 def save(self, filepath, overwrite=True, zipped=True, **kwargs):
#     269     """Saves a model as a `.keras` file.
#     270
#     271     Args:
#    (...)
#     305     Thus models can be reinstantiated in the exact same state.
#     306     """
# --> 307     return saving_api.save_model(
#     308         self, filepath, overwrite=overwrite, zipped=zipped, **kwargs
#     309     )
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/saving/saving_api.py:102, in save_model(model, filepath, overwrite, zipped, **kwargs)
#      99         return
#     101 if zipped and str(filepath).endswith(".keras"):
# --> 102     return saving_lib.save_model(model, filepath)
#     103 if not zipped:
#     104     return saving_lib.save_model(model, filepath, zipped=False)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:103, in save_model(model, filepath, weights_format, zipped)
#     101 else:
#     102     with open(filepath, "wb") as f:
# --> 103         _save_model_to_fileobj(model, f, weights_format)
#
# File /workspaces/solar-project/.venv/lib/python3.10/site-packages/keras/src/saving/saving_lib.py:153, in _save_model_to_fileobj(model, fileobj, weights_format)
#     149         weights_store.close()
#     150         asset_store.close()
# --> 153 def _save_model_to_fileobj(model, fileobj, weights_format):
#     154     config_json, metadata_json = _serialize_model_as_json(model)
#     156     with zipfile.ZipFile(fileobj, "w") as zf:
#
# KeyboardInterrupt:
